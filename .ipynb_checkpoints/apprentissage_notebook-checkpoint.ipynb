# %%
# Tensorflow & Keras
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras import Model

# Autres librairies
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Loading Dataset
train_ds = image_dataset_from_directory(directory='.\data',
                                        subset='training',
                                        validation_split=0.25,
                                        labels='inferred',
                                        label_mode='categorical',
                                        seed=2501,
                                        batch_size=32,
                                        image_size=(256,256))

val_ds = image_dataset_from_directory(directory='.\data',
                                        subset='validation',
                                        validation_split=0.25,
                                        labels='inferred',
                                        label_mode='categorical',
                                        seed=2501,
                                        batch_size=32,
                                        image_size=(256,256))
# Out:
# Found 2000 files belonging to 2 classes.
# Using 1500 files for training.
# Found 2000 files belonging to 2 classes.
# Using 500 files for validation.
# ['dogs', 'wolves']

# %%
# Nom des classes
train_class_names = train_ds.class_names
val_class_names = val_ds.class_names
# Out:
# ['dogs', 'wolves']
# ['dogs', 'wolves']

# %%
# On visualise les données
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")

# %%
# On créer une couche de normalization
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12104/3844284527.py in <module>
#       1 # Normalisation des données
# ----> 2 train_ds = train_ds /255.0
#
# TypeError: unsupported operand type(s) for /: 'BatchDataset' and 'float'

# %%
import os, shutil

# Path to the data dir
base_dir = '.\data'

# Making directories for train, validation and test splits
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)
val_dir = os.path.join(base_dir, 'validation')
os.mkdir(val_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

# Making directories
train_dogs_dir = os.path.join(train_dir, 'dogs')
os.mkdir(train_dogs_dir)
val_dogs_dir = os.path.join(val_dir, 'dogs')
os.mkdir(val_dogs_dir)
